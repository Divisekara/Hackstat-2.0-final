# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_chunk=pd.read_csv("F:\\datathon\\DataSet01.csv",chunksize=1000000)

# %%
chunk_list=[]
for chunk in df_chunk:
    chunk_col1=chunk.iloc[:,0:1]
    chunk_list.append(chunk_col1)
#     chunk_col1=chunk.iloc[:,1:2]
#     chunk_col1=chunk.iloc[:,2:3]
#     chunk_col1=chunk.iloc[:,3:4]
#     chunk_col1=chunk.iloc[:,4:5]
#     chunk_col1=chunk.iloc[:,5:6]
#     chunk_col1=chunk.iloc[:,6:7]
#     chunk_col1=chunk.iloc[:,7:8]
#     chunk_col1=chunk.iloc[:,8:9]
#     chunk_col1=chunk.iloc[:,9:10]    
#     chunk_list.append(chunk_col1)
    
df_concat=pd.concat(chunk_list)
chunk_col1['ONLINE_STORE_CATEGORY'].value_counts().head(6).plot('bar')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (5,6,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (13,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
chunk_list=[]

for chunk in df_chunk:
    chunk_col=chunk.iloc[:,[18,19]]
    chunk_list.append(chunk_col)
#    chunk_col1=chunk.iloc[:,0:1]
#   chunk_list.append(chunk_col1)
#     chunk_col1=chunk.iloc[:,1:2]
#     chunk_col1=chunk.iloc[:,2:3]
#     chunk_col1=chunk.iloc[:,3:4]
#     chunk_col1=chunk.iloc[:,4:5]
#     chunk_col1=chunk.iloc[:,5:6]
#     chunk_col1=chunk.iloc[:,6:7]
#     chunk_col1=chunk.iloc[:,7:8]
#     chunk_col1=chunk.iloc[:,8:9]
#     chunk_col1=chunk.iloc[:,9:10]    
#     chunk_list.append(chunk_col1)
    
df_concat=pd.concat(chunk_list)

chunk_col1['PRD_TYPE'].value_counts().head(6).plot('bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRD_TYPE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-b0c0aef68a30> in <module>
#      18
#      19 df_concat=pd.concat(chunk_list)
# ...

# %%
plt.figure(figsize=(30,15))
df_concat['PRD_TYPE'].value_counts().head(30).plot('bar')

# %%
chunk_list=[]

for chunk in df_chunk:
    chunk_col=chunk.iloc[:,[18,19]]
    chunk_list.append(chunk_col)
#    chunk_col1=chunk.iloc[:,0:1]
#   chunk_list.append(chunk_col1)
#     chunk_col1=chunk.iloc[:,1:2]
#     chunk_col1=chunk.iloc[:,2:3]
#     chunk_col1=chunk.iloc[:,3:4]
#     chunk_col1=chunk.iloc[:,4:5]
#     chunk_col1=chunk.iloc[:,5:6]
#     chunk_col1=chunk.iloc[:,6:7]
#     chunk_col1=chunk.iloc[:,7:8]
#     chunk_col1=chunk.iloc[:,8:9]
#     chunk_col1=chunk.iloc[:,9:10]    
#     chunk_list.append(chunk_col1)
    
df_concat=pd.concat(chunk_list)

plt.figure(figsize=(30,15))
df_concat['PRD_TYPE'].value_counts().head(30).plot('bar')
#chunk_col1['PRD_TYPE'].value_counts().head(6).plot('bar')

# %%
df_concat
# Out:
#                       PRD_TYPE          PRD_SUBTYPE
# 3000000           LEVI'S LONGS   569 LOOSE STRAIGHT
# 3000001   WOMENS ATHLETIC SHOE         NIKE RUNNING
# 3000002            NB/INF GIRL   FALL INF BODYSUITS
# 3000003          UPDATED PANTS            BOY SHORT
# 3000004   WOMENS ATHLETIC SHOE         FILA RUNNING
# 3000005               SLIPPERS           TOTES MENS
# 3000006   WOMENS CASUAL BOTTMS      BASIC DENIM-AMA
# 3000007                 FRAMES               MALDEN
# 3000008                 EC ART       MEDIUM (15-21)
# 3000009        SMALL ELECTRICS        HAND BLENDERS
# 3000010      INF TOD SLEEPWEAR  TOD BOY BLANKET SLP
# 3000011                BRANDED                 BRAS
# 3000012                 FRAMES             NEW VIEW
# 3000013       WOMENS SLEEPWEAR                 SETS
# 3000014       TODDLER ATHLETIC        CONVERSE CORE
# 3000015         CROFT & BARROW          LONG SLEEVE
# 3000016    MENS ACTIVE APPAREL                PANTS
# ...

# %%
df_concat1=df_concat[df_concat['PRD_TYPE']=='SHORTS']
df_concat1
# Out:
#          PRD_TYPE           PRD_SUBTYPE
# 8781337    SHORTS      BOYS 8-20 ACTIVE
# 8784575    SHORTS      BOYS 8-20 ACTIVE
# 8784591    SHORTS            MISSES LEE
# 8784623    SHORTS   MENS ACTIVE APPAREL
# 8784656    SHORTS        WOMENS UPDATED
# 8785151    SHORTS    G 4/6X PRIV BRANDS
# 8785211    SHORTS  ACTIVE PRIVATE BRAND
# 8785402    SHORTS               BRANDED
# 8785467    SHORTS  ACTIVE PRIVATE BRAND
# 8785967    SHORTS          TODDLER BOYS
# 8786067    SHORTS          TODDLER BOYS
# 8786075    SHORTS          TODDLER BOYS
# 8786091    SHORTS        WOMENS UPDATED
# 8786101    SHORTS      BOYS 8-20 ACTIVE
# 8786108    SHORTS    OUTDOOR RECREATION
# 8786130    SHORTS            MISSES LEE
# 8786152    SHORTS      BOYS 8-20 ACTIVE
# 8786163    SHORTS    OUTDOOR RECREATION
# 8787488    SHORTS          TODDLER BOYS
# 8787597    SHORTS          TODDLER BOYS
# 8787740    SHORTS               BRANDED
# 8787792    SHORTS  ACTIVE PRIVATE BRAND
# ...

# %%
plt.figure(figsize=(30,15))
df_concat1['PRD_SUBTYPE'].value_counts().head(30).plot('bar')
