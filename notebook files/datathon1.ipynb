# %%
import pandas as pd
trainset = pd.read_csv("C:\\Users\\ASUS\\Desktop\\online_&_slsdate.csv")
trainset3 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\ONLINE_STORE_CATEGORY.csv")
trainset4 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\TRN_SLS_DTE.csv")
trainset5 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\TRN_STRT_TM.csv")
trainset6 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\online_&_slsdate.csv")
trainset7 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\online_&_slsdate.csv")
trainset8 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\online_&_slsdate.csv")
trainset9 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\online_&_slsdate.csv")

# %%
trainset1 = trainset
trainset1
# Out:
#          ONLINE_STORE_CATEGORY  PRODUCT_CLASS_02
# 0                    384109217        1839971306
# 1                    384109217        1839971306
# 2                    384109217        1839971306
# 3                    384109217         572054888
# 4                     73168914        1553426509
# 5                     73168914        1781902150
# 6                     73168914        1264041405
# 7                    384109217        1922781656
# 8                      1631220        2057697038
# 9                   1390981718        1727461350
# 10                    73168914        1967211027
# 11                    73168914          49205683
# 12                  1841427194         415958262
# 13                   658917596        1553426509
# 14                    73168914         439580624
# 15                  1193501398         130178939
# 16                  2100358791        1820427731
# 17                   658917596        1382111110
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
x = trainset1['ONLINE_STORE_CATEGORY']
y = trainset1['PRODUCT_CLASS_02']
colors = (0,0,0)

# Plot
plt.figure(figsize=(20,10))
plt.scatter(x, y,  c=colors, alpha=0.5)
plt.title('ONLINE_STORE_CATEGORY vs ')
plt.xlabel('ONLINE_STORE_CATEGORY')
plt.ylabel('PRODUCT_CLASS_02')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
trainset1['ONLINE_STORE_CATEGORY'].value_counts().head(6).plot('bar')

# %%
trainset1['ONLINE_STORE_CATEGORY'].value_counts()
# Out:
# 384109217      257188
# 73168914       146078
# 1465291146      89767
# 1390981718      80137
# 1841427194      76215
# 375142417        2808
# 179211848        2460
# 11810244211      2358
# 1311045163       2277
# 11261317924      1653
# 1788317921       1292
# 1701701408       1240
# 12120424471      1106
# 1714620922       1058
# 1991913349       1052
# 11850146637      1048
# 1236182943       1047
# 523324626        1045
# 922889115         974
# 162620251         940
# 11815879456       932
# 11523497880       930
# 1767393933        923
# 11508456377       921
# 1553761879        918
# 161207350         914
# 658917596         887
# 949260025         884
# 291956501         881
# 1202348136        881
#                 ...
# 11909022834       115
# 1857754470        114
# 283167874         113
# 131907655         113
# 11461601197       111
# 631830185         110
# 274972092         109
# 1791511783        109
# 11724975971       108
# 11602868116       108
# ...

# %%
plt.figure(figsize=(20,10))
trainset1['PRODUCT_CLASS_02'].value_counts().plot('bar')

# %%
trainset2 = pd.read_csv("C:\\Users\\ASUS\\Desktop\\product_return.csv")

# %%
trainset2
# Out:
#          PRIMARY_PRODUCT_CODE  RETURN_INDICATION              PRD_TYPE
# 0                    30686824                  0         CLASSIC PANTS
# 1                    30686824                  0         CLASSIC PANTS
# 2                    30686824                  0         CLASSIC PANTS
# 3                   747315192                  0    WVNS/SWTRS/OUTERWR
# 4                  1718192178                  0      LC LAUREN CONRAD
# 5                 12117995491                  0    G 4/6X PRIV BRANDS
# 6                   597761991                  1  WOMENS ATHLETIC SHOE
# 7                  1365908237                  0      SILVER OPEN SELL
# 8                  1814390980                  0      YOUNG MENS LONGS
# 9                    18427037                  0          TODDLER BOYS
# 10                 1687376809                  0          TABLE LINENS
# 11                11286051383                  0     MENS CASUAL PANTS
# ...

# %%
trainset2['PRIMARY_PRODUCT_CODE'].value_counts().head(50).plot('bar')

# %%
trainset2['PRIMARY_PRODUCT_CODE'].value_counts()
# Out:
# 1974243099     1424
# 231909421       685
# 591350016       566
# 11860601190     552
# 11432094650     497
# 1760402374      458
# 1669152186      453
# 2133140169      427
# 49780428        425
# 1044364300      421
# 11844123696     392
# 11116250244     389
# 658553223       388
# 11137562564     370
# 1615594627      365
# 1388835165      359
# 11350927609     350
# 2088814701      348
# 1478241617      346
# 463149205       343
# 1729776757      337
# 1189833859      328
# 157195338       321
# 115518510       318
# 2071807255      304
# 1327310026      292
# 1425029867      290
# 11673209749     290
# 11485452005     287
# 139345256       287
#                ...
# 1022386861        1
# 913735525         1
# 2083846718        1
# 261392944         1
# 1289910244        1
# 11275631150       1
# 2140431770        1
# 1371212637        1
# 1160387042        1
# 2050642411        1
# 12065069024       1
# 483029487         1
# 1293133790        1
# 206815197         1
# ...

# %%
trainset2['RETURN_INDICATION'].value_counts()
# Out:
# 0    933778
# 1    114797
# Name: RETURN_INDICATION, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
x = trainset2['PRIMARY_PRODUCT_CODE']
y = trainset2['RETURN_INDICATION']
colors = (0,0,0)

# Plot
plt.figure(figsize=(20,10))
plt.scatter(x, y,  c=colors, alpha=0.5)
plt.title('RETURN_INDICATION vs PRIMARY_PRODUCT_CODE')
plt.xlabel('PRIMARY_PRODUCT_CODE')
plt.ylabel('RETURN_INDICATION')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
trainset2['PRD_TYPE'].value_counts()
# Out:
# LAYETTE                 41991
# ACTIVE PRIVATE BRAND    28278
# INF TOD SLEEPWEAR       22337
# TODDLER GIRLS           22197
# APT 9 TOPS              21942
# TODDLER BOYS            21453
# TOWELS                  20830
# NB/INF GIRL             20735
# SMALL ELECTRICS         20175
# WOMENS ATHLETIC SHOE    19003
# CROFT & BARROW          18416
# INF&TOD BASICS&ACCES    15019
# WOMENS BOOTS            14630
# MENS ACTIVE APPAREL     14613
# CLASSIC BRAS            14079
# NB/INF BOY              13924
# TABLE LINENS            13693
# G 4/6X PRIV BRANDS      13249
# MISSES SONOMA TOPS      13217
# WOMENS SLEEPWEAR        13051
# PILLOWS & PADS          12797
# WOMENS UPDATED          12358
# EC WINDOW               10919
# BLANKETS/DOWN/THROWS    10507
# WOMENS CLASSC SEPRTS    10202
# WOMENS SOCKS            10032
# EC BABY NON-APPAREL      9797
# FOOD PREP                9785
# MENS ATHLETIC SHOES      9667
# TABLEWARE                9508
#                         ...
# ...

# %%
trainset2['PRD_TYPE'].value_counts()
# Out:
# LAYETTE                 41991
# ACTIVE PRIVATE BRAND    28278
# INF TOD SLEEPWEAR       22337
# TODDLER GIRLS           22197
# APT 9 TOPS              21942
# TODDLER BOYS            21453
# TOWELS                  20830
# NB/INF GIRL             20735
# SMALL ELECTRICS         20175
# WOMENS ATHLETIC SHOE    19003
# CROFT & BARROW          18416
# INF&TOD BASICS&ACCES    15019
# WOMENS BOOTS            14630
# MENS ACTIVE APPAREL     14613
# CLASSIC BRAS            14079
# NB/INF BOY              13924
# TABLE LINENS            13693
# G 4/6X PRIV BRANDS      13249
# MISSES SONOMA TOPS      13217
# WOMENS SLEEPWEAR        13051
# PILLOWS & PADS          12797
# WOMENS UPDATED          12358
# EC WINDOW               10919
# BLANKETS/DOWN/THROWS    10507
# WOMENS CLASSC SEPRTS    10202
# WOMENS SOCKS            10032
# EC BABY NON-APPAREL      9797
# FOOD PREP                9785
# MENS ATHLETIC SHOES      9667
# TABLEWARE                9508
#                         ...
# ...

# %%
df_full = pd.read_csv("C:\\Users\\ASUS\\Desktop\\DataSet01.csv", chunksize = 1000000)

# %%
df_full

# %%
chunk_list1 = []
chunk_list2 = []
chunk_list3 = []
chunk_list4 = []
chunk_list5 = []
chunk_list6 = []
chunk_list7 = []
chunk_list8 = []
chunk_list9 = []
chunk_list10 = []
for chunk in df_full:
    chunk_col1 = chunk.iloc[:,0:1]
    chunk_list1.append(chunk_col1)
    chunk_col2 = chunk.iloc[:,1:2]
    chunk_list2.append(chunk_col2)
    chunk_col3 = chunk.iloc[:,5:6]
    chunk_list3.append(chunk_col3)
    chunk_col4 = chunk.iloc[:,6:7]
    chunk_list4.append(chunk_col4)
    chunk_col5 = chunk.iloc[:,8:9]
    chunk_list5.append(chunk_col5)
    chunk_col6 = chunk.iloc[:,10:11]
    chunk_list6.append(chunk_col6)
    chunk_col7 = chunk.iloc[:,12:13]
    chunk_list7.append(chunk_col7)
    chunk_col8 = chunk.iloc[:,13:14]
    chunk_list8.append(chunk_col8)
    chunk_col9 = chunk.iloc[:,20:21]
    chunk_list9.append(chunk_col9)
df_concat1 = pd.concat(chunk_list1)
df_concat2 = pd.concat(chunk_list2)
df_concat1 = pd.concat(chunk_list3)
df_concat2 = pd.concat(chunk_list4)
df_concat1 = pd.concat(chunk_list5)
df_concat2 = pd.concat(chunk_list6)
df_concat1 = pd.concat(chunk_list7)
df_concat2 = pd.concat(chunk_list8)
df_concat1 = pd.concat(chunk_list9)

# %%
chunk_col1['ONLINE_STORE_CATEGORY'].value_counts().head(6).plot('bar')

# %%
df_concat

# %%
chunk_col1['ONLINE_STORE_CATEGORY'].value_counts().head(6).plot('bar')
