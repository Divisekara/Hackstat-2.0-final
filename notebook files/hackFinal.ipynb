# %%
import pandas as pd
import numpy as np

df= pd.read_excel("E:\\hack\\insurance_syn_hackathon_phase1.xlsx")
df
# Out:
#           ID  TENURE_QUINTILES  payment_pr1q_mean_diff_days  \
# 0          1                 1                    -4.151475
# 1          2                 2                    -5.476620
# 2          3                 2                    14.498615
# 3          4                 0                    23.824406
# 4          5                 0                     0.931913
# 5          6                 2                   -22.163258
# 6          7                 2                    52.431916
# 7          8                 1                   -17.336019
# 8          9                 0                   -17.728233
# 9         10                 1                   -18.548074
# 10        11                 1                   -30.980943
# 11        12                 1                   -34.258248
# 12        13                 0                    51.210238
# 13        14                 0                   -36.763445
# 14        15                 0                    68.131871
# ...
